# %%
import pandas as pd

df = pd.read_csv('penguins_lter.csv')
clean_df = df.dropna()
df1 = df.fillna({'Sex':'etc','Delta 15 N (o/oo)':0,'Delta 13 C (o/oo)':0,'Comments':'etc'})
print(df1.isna().sum())
# Out:
# studyName              0
# Sample Number          0
# Species                0
# Region                 0
# Island                 0
# Stage                  0
# Individual ID          0
# Clutch Completion      0
# Date Egg               0
# Culmen Length (mm)     2
# Culmen Depth (mm)      2
# Flipper Length (mm)    2
# Body Mass (g)          2
# Sex                    0
# Delta 15 N (o/oo)      0
# Delta 13 C (o/oo)      0
# Comments               0
# dtype: int64
